# %%
import time
from onrobot import RG

GRIPPER_NAME = "rg2"
TOOLCHARGER_IP = "192.168.1.1"
TOOLCAHRGER_PORT = "502"

gripper = RG(GRIPPER_NAME, TOOLCHARGER_IP, TOOLCAHRGER_PORT)

# %%
gripper.open_gripper()
# gripper.close_gripper()
# gripper.move_gripper(800)
# Out:
# Start opening gripper.
